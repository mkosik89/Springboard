# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# # Get Data

# %%
# plt.style.use('ggplot')
plt.style.use('seaborn')

# %%
f = r'C:\Users\mattk\code\Mkt_Data\all_futures.csv'
df = pd.read_csv(f,index_col=0,parse_dates=[0])
df = df.resample('1B').last()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13112 entries, 1970-03-30 to 2020-06-30
# Freq: B
# Data columns (total 38 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AEX      2790 non-null   float64
#  1   AUD      8423 non-null   float64
#  2   BOBL     3191 non-null   float64
#  3   BTP      2680 non-null   float64
#  4   BUND     3513 non-null   float64
#  5   CAC      2877 non-null   float64
#  6   COPPER   6331 non-null   float64
#  7   CORN     12248 non-null  float64
#  8   CRUDE_W  7868 non-null   float64
#  9   EDOLLAR  9262 non-null   float64
#  10  EUR      5328 non-null   float64
#  11  EUROSTX  1566 non-null   float64
#  12  GAS_US   7560 non-null   float64
#  13  GBP      11327 non-null  float64
#  14  GOLD     11411 non-null  float64
#  15  JPY      10932 non-null  float64
#  16  KOSPI    1532 non-null   float64
#  17  KR10     1520 non-null   float64
#  18  KR3      1515 non-null   float64
#  19  LEANHOG  11856 non-null  float64
#  20  LIVECOW  12537 non-null  float64
#  21  MXP      6301 non-null   float64
#  22  NASDAQ   5308 non-null   float64
#  23  NZD      4392 non-null   float64
#  24  OAT      2039 non-null   float64
#  25  PALLAD   10872 non-null  float64
#  26  PLAT     12659 non-null  float64
#  27  SHATZ    3254 non-null   float64
#  28  SMI      1540 non-null   float64
#  29  SOYBEAN  9419 non-null   float64
#  30  SP500    5729 non-null   float64
#  31  US10     9594 non-null   float64
#  32  US2      5137 non-null   float64
#  33  US20     10670 non-null  float64
#  34  US5      7895 non-null   float64
#  35  V2X      1935 non-null   float64
#  36  VIX      3657 non-null   float64
#  37  WHEAT    12224 non-null  float64
# dtypes: float64(38)
# memory usage: 3.9 MB

# %%
# assets = ['COPPER', 'CORN', 'CRUDE_W',
#        'EUR', 'GBP', 'GOLD', 'JPY',
#        'LEANHOG', 'LIVECOW', 'MXP',
#        'PALLAD', 'PLAT', 'SOYBEAN', 'SP500', 'US10', 'WHEAT']

# used for all binary 1/-1 combinations as there are too many combinations and simulation takes a long time

# %%
assets = ['AUD', 'COPPER', 'CORN', 'CRUDE_W',
       'EDOLLAR', 'EUR', 'GAS_US', 'GBP', 'GOLD', 'JPY',
       'LEANHOG', 'LIVECOW', 'MXP', 'NASDAQ',
       'PALLAD', 'PLAT', 'SOYBEAN', 'SP500', 'US10', 'US2',
       'US20', 'US5', 'WHEAT']

# %%
df2 = df[assets].loc['1/1/2000':'1/1/2020']

# %%
df2.head()
# Out:
#                AUD  COPPER    CORN  CRUDE_W   EDOLLAR      EUR  GAS_US  \
# DATETIME
# 2000-01-03  0.3264     NaN  592.25      NaN  84.68998  1.19005     NaN
# 2000-01-04  0.3204  1.2060  593.25    12.34  84.74498  1.19235  23.123
# 2000-01-05  0.3227  1.2145  593.75    12.02  84.65498  1.19405  23.120
# 2000-01-06  0.3200  1.2110  594.75    11.95  84.69498  1.19205  23.156
# 2000-01-07  0.3204  1.2120  597.50    12.03  84.75498  1.19035  23.140
#
#                GBP   GOLD       JPY  ...  NASDAQ  PALLAD   PLAT  SOYBEAN  \
# DATETIME                             ...
# 2000-01-03  1.5057    NaN  0.013691  ...  4489.5     NaN    NaN    33.25
# 2000-01-04  1.5035  649.2  0.013518  ...  4202.5   574.3  561.0    39.25
# 2000-01-05  1.5083  647.6  0.013410  ...  4157.5   570.5  549.2    45.50
# 2000-01-06  1.5139  647.9  0.013305  ...  3957.5   567.7  541.3    44.75
# 2000-01-07  1.5049  648.4  0.013323  ...  4202.5   576.3  543.3    48.75
#
#                SP500       US10        US2      US20        US5   WHEAT
# DATETIME
# 2000-01-03  1504.375  36.265615  81.882818  32.96855  54.101567  888.25
# 2000-01-04  1449.375  36.742177  82.007818  33.71855  54.429692  887.00
# 2000-01-05  1451.375  36.062490  81.875005  32.78155  54.062505  891.00
# 2000-01-06  1441.375  36.390615  81.945318  33.49955  54.234380  890.50
# 2000-01-07  1498.375  36.765615  82.015630  34.03155  54.453130  893.25
#
# [5 rows x 23 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5218 entries, 2000-01-03 to 2020-01-01
# Freq: B
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AUD      5064 non-null   float64
#  1   COPPER   4990 non-null   float64
#  2   CORN     5022 non-null   float64
#  3   CRUDE_W  4939 non-null   float64
#  4   EDOLLAR  5029 non-null   float64
#  5   EUR      5008 non-null   float64
#  6   GAS_US   5023 non-null   float64
#  7   GBP      5067 non-null   float64
#  8   GOLD     5017 non-null   float64
#  9   JPY      5049 non-null   float64
#  10  LEANHOG  5012 non-null   float64
#  11  LIVECOW  5013 non-null   float64
#  12  MXP      5028 non-null   float64
#  13  NASDAQ   5104 non-null   float64
#  14  PALLAD   5024 non-null   float64
#  15  PLAT     5062 non-null   float64
#  16  SOYBEAN  4934 non-null   float64
#  17  SP500    5019 non-null   float64
#  18  US10     5030 non-null   float64
#  19  US2      4924 non-null   float64
#  20  US20     5035 non-null   float64
#  21  US5      5035 non-null   float64
#  22  WHEAT    5024 non-null   float64
# dtypes: float64(23)
# memory usage: 978.4 KB

# %%
df3 = df2.fillna(method='ffill')
df3 = df3.diff().dropna()
tgt_vol = .15/np.sqrt(252)
df3 = (df3*tgt_vol/df3.ewm(span=25).std()).dropna()

# %%
sns.clustermap(df3.corr(),figsize=(12, 10),cmap='coolwarm')

# %%
np.mean(df3,axis=0)*252/2
# Out:
# AUD        0.028108
# COPPER     0.019450
# CORN      -0.008596
# CRUDE_W    0.045744
# EDOLLAR    0.051035
# EUR        0.004206
# GAS_US    -0.020009
# GBP        0.006512
# GOLD       0.046995
# JPY       -0.035982
# LEANHOG    0.026426
# LIVECOW    0.008755
# MXP        0.028909
# NASDAQ     0.051615
# PALLAD     0.039863
# PLAT       0.036050
# SOYBEAN    0.035872
# SP500      0.044450
# US10       0.056419
# US2        0.045147
# US20       0.052530
# US5        0.053174
# WHEAT     -0.005916
# dtype: float64

# %%
df3.head()
# Out:
#                  AUD    COPPER      CORN   CRUDE_W   EDOLLAR       EUR  \
# DATETIME
# 2000-01-06 -0.007216 -0.003898  0.026726 -0.003742  0.004112 -0.007223
# 2000-01-07  0.001522  0.001595  0.021714  0.003767  0.007082 -0.007991
# 2000-01-10  0.004155 -0.010467  0.017090  0.011946 -0.006691 -0.013731
# 2000-01-11  0.008997 -0.004858 -0.003713  0.013294 -0.013896  0.015428
# 2000-01-12  0.000000  0.018222  0.023310  0.008006 -0.004829 -0.003479
#
#               GAS_US       GBP      GOLD       JPY  ...    NASDAQ    PALLAD  \
# DATETIME                                            ...
# 2000-01-06  0.012335  0.093541  0.002110 -0.467707  ... -0.017243 -0.037417
# 2000-01-07 -0.005525 -0.010152  0.004152  0.002322  ...  0.010023  0.011592
# 2000-01-10  0.011668 -0.002512 -0.002076  0.001361  ...  0.009421  0.011358
# 2000-01-11  0.014104  0.013296  0.013517 -0.011089  ... -0.008421 -0.003853
# 2000-01-12 -0.002708  0.000000 -0.005909 -0.000333  ... -0.003473  0.004896
#
#                 PLAT   SOYBEAN     SP500      US10       US2      US20  \
# DATETIME
# 2000-01-06 -0.027069 -0.001432 -0.011136  0.004351  0.004626  0.005797
# 2000-01-07  0.002629  0.010721  0.014747  0.006065  0.005784  0.005671
# 2000-01-10  0.003326 -0.008755  0.004518 -0.004680 -0.009373 -0.004685
# 2000-01-11 -0.000766  0.005107 -0.006485  0.000000 -0.012719  0.000000
# 2000-01-12  0.006681  0.013109 -0.004021 -0.016538 -0.006111 -0.014400
#
#                  US5     WHEAT
# DATETIME
# 2000-01-06  0.004261 -0.001485
# 2000-01-07  0.006469  0.011317
# 2000-01-10 -0.007257  0.013883
# 2000-01-11 -0.013119  0.000000
# 2000-01-12 -0.006204  0.020979
#
# [5 rows x 23 columns]

# %%
des = df3.describe().T
des = des.loc[:,['mean','std']]
des[['mean']] = des[['mean']]*252
des[['std']] = des[['std']]*np.sqrt(252)
des['Sharpe'] = des['mean']/des['std']

# %%
des
# Out:
#              mean       std    Sharpe
# AUD      0.056216  0.144384  0.389349
# COPPER   0.038900  0.143950  0.270233
# CORN    -0.017191  0.143293 -0.119973
# CRUDE_W  0.091488  0.144402  0.633565
# EDOLLAR  0.102070  0.144187  0.707903
# EUR      0.008412  0.144293  0.058300
# GAS_US  -0.040018  0.144611 -0.276729
# GBP      0.013024  0.145700  0.089392
# GOLD     0.093991  0.142983  0.657355
# JPY     -0.071964  0.175916 -0.409083
# LEANHOG  0.052851  0.144687  0.365280
# LIVECOW  0.017509  0.144538  0.121138
# MXP      0.057817  0.143863  0.401891
# NASDAQ   0.103229  0.143178  0.720986
# PALLAD   0.079726  0.145060  0.549608
# PLAT     0.072100  0.144754  0.498087
# SOYBEAN  0.071745  0.143631  0.499507
# SP500    0.088901  0.142701  0.622985
# US10     0.112837  0.144260  0.782180
# US2      0.090295  0.142302  0.634530
# US20     0.105059  0.144551  0.726799
# US5      0.106349  0.143880  0.739152
# WHEAT   -0.011832  0.144365 -0.081960

# %% [markdown]
# # Long Only

# %%
# long only
print('Long Only')
print('Return: {}'.format(df3.mean(axis=1).mean()*252))
print('Std: {}'.format(df3.mean(axis=1).std()*np.sqrt(252)))
print('Sharpe: {}'.format(df3.mean(axis=1).mean()*np.sqrt(252)/df3.mean(axis=1).std()))
# Out:
# Long Only
# Return: 0.05310929800093107
# Std: 0.05837279149276344
# Sharpe: 0.9098296765114463

# %%
print('Best Possible Sharpe: {}'.format(df3.abs().mean(axis=1).mean()*np.sqrt(252)/df3.mean(axis=1).std()))
# Out:
# Best Possible Sharpe: 30.605178918131262

# %%
def plot_hists2(arr):
    fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(20,16))

    ax[0,0].hist(np.mean(arr,axis=0)*252,bins=50)
    v = ax[0,0].get_xticks()
    ax[0,0].set_xticklabels(['{:,.2%}'.format(x) for x in v])
    ax[0,0].set_title('Annualized % Returns');
    ax[0,0].set_xlabel('Annualized Portfolio Return')
    ax[0,0].set_ylabel('Count')

    ax[0,1].hist(np.std(arr,axis=0)*np.sqrt(252),bins=50)
    ax[0,1].set_title('Annualized % Vol');
    v = ax[0,1].get_xticks()
    ax[0,1].set_xticklabels(['{:,.2%}'.format(x) for x in v])
    ax[0,1].set_xlabel('Annualized Portfolio Vol')
    ax[0,1].set_ylabel('Count')

    ax[1,0].hist(np.mean(arr,axis=0)*np.sqrt(252)/np.std(arr,axis=0),bins=50)
    ax[1,0].set_title('Annualized Sharpe');
    ax[1,0].set_xlabel('Sharpe')
    ax[1,0].set_ylabel('Count')
    
    ax[1,1].scatter(np.std(arr,axis=0)*np.sqrt(252),np.mean(arr,axis=0)*np.sqrt(252)/np.std(arr,axis=0),alpha=.7)
    ax[1,1].set_title('Sharpe vs. Std.')
    ax[1,1].set_xlabel('Std.')
    ax[1,1].set_ylabel('Sharpe');
    
    return

# %% [markdown]
# # Random Days, Random Wts [-1,1]

# %%
# choose 2,500 random days with replacement 
# simulate 10,000 wt combos [-1,1] for each asset each day

choice = np.random.choice(range(len(df3)),2500)
days = df3.iloc[choice,:].to_numpy()
pos = np.random.uniform(-1,1,size=(df3.shape[1],10000))
d_ret = (days.dot(pos))/days.shape[1]

# %%
plot_hists2(d_ret)
# Out:
# <ipython-input-143-13c705cd152c>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0,0].set_xticklabels(['{:,.2%}'.format(x) for x in v])
# <ipython-input-143-13c705cd152c>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0,1].set_xticklabels(['{:,.2%}'.format(x) for x in v])

# %%
random_sharpes = np.mean(d_ret,axis=0)*np.sqrt(252)/np.std(d_ret,axis=0)
plt.hist(random_sharpes,bins=50);
print('99th Percentile Sharpe: {}'.format(np.quantile(random_sharpes,.99)))
# Out:
# 99th Percentile Sharpe: 1.1665470750728084

# %% [markdown]
# # Random Days, Random Wts Binary -1 or 1

# %%
# choose 2,500 random days with replacement 
# simulate 10,000 wt combos binary -1 or 1 for each asset each day

choice = np.random.choice(range(len(df3)),2500)
days = df3.iloc[choice,:].to_numpy()
pos = np.random.choice([-1,1],size=(df3.shape[1],10000))
d_ret = (days.dot(pos))/days.shape[1]

# %%
plot_hists2(d_ret)
# Out:
# <ipython-input-143-13c705cd152c>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0,0].set_xticklabels(['{:,.2%}'.format(x) for x in v])
# <ipython-input-143-13c705cd152c>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0,1].set_xticklabels(['{:,.2%}'.format(x) for x in v])

# %%
random_sharpes = np.mean(d_ret,axis=0)*np.sqrt(252)/np.std(d_ret,axis=0)
plt.hist(random_sharpes,bins=50);
print('99th Percentile Sharpe: {}'.format(np.quantile(random_sharpes,.99)))
# Out:
# 99th Percentile Sharpe: 1.253804698374378

# %% [markdown]
# # All Possible -1,1 combinations

# %%
# choose 1,000 random days with replacement or All days
# use all possible 1 or -1 weight combinations

choice = np.random.choice(range(len(df3)),1000)
days = df3.iloc[choice,:].to_numpy()

num  = df3.shape[1]
all_pos = np.array(np.meshgrid(*[[-1,1]]*num,indexing='ij')).reshape(num,-1)

# d_ret = (days.dot(all_pos))/days.shape[1]
d_ret = df3.to_numpy().dot(all_pos)/days.shape[1] # use all days
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-99-5641ed561611> in <module>
#       9
#      10 # d_ret = (days.dot(all_pos))/days.shape[1]
# ---> 11 d_ret = df3.to_numpy().dot(all_pos)/days.shape[1] # use all days
#
# MemoryError: Unable to allocate 326. GiB for an array with shape (5215, 8388608) and data type float64

# %%
plot_hists2(d_ret)

# %%
random_sharpes = np.mean(d_ret,axis=0)*np.sqrt(252)/np.std(d_ret,axis=0)
plt.hist(random_sharpes,bins=50);
print('99th Percentile Sharpe: {}'.format(np.quantile(random_sharpes,.99)))

# %% [markdown]
# # Correlation impact on variance reduction for multiple assets

# %%
def var_cor(n, p):

    # equal weight zero correlation
    n_assets = n
    Astd = .15 # std for all assets
    p = p
    cov_m = np.full((n_assets,n_assets),p*np.sqrt((Astd**2)**2))
#     cov_m = np.random.normal(p*np.sqrt((Astd**2)**2),.001,size=(n_assets,n_assets))
#     cov_m = cov_m + cov_m.T - np.diag(np.diag(cov_m))
    np.fill_diagonal(cov_m,Astd**2)
    # cov_m = np.eye(n_assets)*(Astd**2)
    wts = np.ones(n_assets)/n_assets
#     print(cov_m)

    return np.sqrt(wts.dot(cov_m).dot(wts.T))

# %%
plt.figure(figsize=(12,8))
for n in range(2,16,2):
    plt.plot(np.linspace(-1,1,1000),[var_cor(n,i) for i in np.linspace(-1,1,1000)],label='{} assets'.format(n))
plt.legend()
plt.xlabel('Correlation')
plt.ylabel('Portfolio Vol')
# Out:
# <ipython-input-149-f3f2ad89deeb>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(wts.dot(cov_m).dot(wts.T))
# <ipython-input-149-f3f2ad89deeb>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(wts.dot(cov_m).dot(wts.T))
# <ipython-input-149-f3f2ad89deeb>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(wts.dot(cov_m).dot(wts.T))
# <ipython-input-149-f3f2ad89deeb>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(wts.dot(cov_m).dot(wts.T))
# <ipython-input-149-f3f2ad89deeb>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(wts.dot(cov_m).dot(wts.T))
# <ipython-input-149-f3f2ad89deeb>:15: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(wts.dot(cov_m).dot(wts.T))
# Text(0, 0.5, 'Portfolio Vol')
