# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression,Lasso

from scipy.optimize import minimize

# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
f = r'C:\Users\mattk\code\Mkt_Data\all_futures.csv'
df = pd.read_csv(f,index_col=0,parse_dates=[0])
df = df.resample('1B').last()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13112 entries, 1970-03-30 to 2020-06-30
# Freq: B
# Data columns (total 38 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AEX      2790 non-null   float64
#  1   AUD      8423 non-null   float64
#  2   BOBL     3191 non-null   float64
#  3   BTP      2680 non-null   float64
#  4   BUND     3513 non-null   float64
#  5   CAC      2877 non-null   float64
#  6   COPPER   6331 non-null   float64
#  7   CORN     12248 non-null  float64
#  8   CRUDE_W  7868 non-null   float64
#  9   EDOLLAR  9262 non-null   float64
#  10  EUR      5328 non-null   float64
#  11  EUROSTX  1566 non-null   float64
#  12  GAS_US   7560 non-null   float64
#  13  GBP      11327 non-null  float64
#  14  GOLD     11411 non-null  float64
#  15  JPY      10932 non-null  float64
#  16  KOSPI    1532 non-null   float64
#  17  KR10     1520 non-null   float64
#  18  KR3      1515 non-null   float64
#  19  LEANHOG  11856 non-null  float64
#  20  LIVECOW  12537 non-null  float64
#  21  MXP      6301 non-null   float64
#  22  NASDAQ   5308 non-null   float64
#  23  NZD      4392 non-null   float64
#  24  OAT      2039 non-null   float64
#  25  PALLAD   10872 non-null  float64
#  26  PLAT     12659 non-null  float64
#  27  SHATZ    3254 non-null   float64
#  28  SMI      1540 non-null   float64
#  29  SOYBEAN  9419 non-null   float64
#  30  SP500    5729 non-null   float64
#  31  US10     9594 non-null   float64
#  32  US2      5137 non-null   float64
#  33  US20     10670 non-null  float64
#  34  US5      7895 non-null   float64
#  35  V2X      1935 non-null   float64
#  36  VIX      3657 non-null   float64
#  37  WHEAT    12224 non-null  float64
# dtypes: float64(38)
# memory usage: 3.9 MB

# %%
for c in df.columns:
    print(c+' : '+df[c].first_valid_index().strftime('%m-%d-%Y'))
# Out:
# AEX : 07-16-2009
# AUD : 03-16-1987
# BOBL : 12-04-2007
# BTP : 12-03-2009
# BUND : 09-01-2006
# CAC : 03-16-2009
# COPPER : 02-28-1995
# CORN : 10-18-1971
# CRUDE_W : 11-02-1988
# EDOLLAR : 09-29-1983
# EUR : 03-15-1999
# EUROSTX : 12-12-2013
# GAS_US : 05-24-1990
# GBP : 09-15-1975
# GOLD : 01-29-1975
# JPY : 03-14-1977
# KOSPI : 12-10-2013
# KR10 : 12-16-2013
# KR3 : 12-16-2013
# LEANHOG : 05-16-1973
# LIVECOW : 09-01-1970
# MXP : 06-14-1995
# NASDAQ : 09-13-1999
# NZD : 12-10-2002
# OAT : 06-04-2012
# PALLAD : 02-28-1977
# PLAT : 03-30-1970
# SHATZ : 09-04-2007
# SMI : 12-11-2013
# SOYBEAN : 09-16-1982
# SP500 : 09-11-1997
# US10 : 05-27-1982
# US2 : 08-31-1999
# US20 : 02-24-1978
# US5 : 02-24-1989
# V2X : 11-12-2012
# VIX : 11-22-2005
# WHEAT : 12-13-1971

# %%
assets = ['AUD', 'COPPER', 'CORN', 'CRUDE_W',
       'EDOLLAR', 'EUR', 'GAS_US', 'GBP', 'GOLD', 'JPY',
       'LEANHOG', 'LIVECOW', 'MXP', 'NASDAQ',
       'PALLAD', 'PLAT', 'SOYBEAN', 'SP500', 'US10', 'US2',
       'US20', 'US5', 'WHEAT']

# %%
df2 = df[assets].loc['1/1/2000':'1/1/2020']

# %%
df2.describe().T.sort_values('count')
# Out:
#           count         mean          std          min          25%  \
# US2      4924.0   100.312660     7.991932    81.187505    94.425786
# SOYBEAN  4934.0   640.008455   453.684479   -73.500000   194.312500
# CRUDE_W  4939.0    63.599036    28.073915    11.950000    43.825000
# COPPER   4990.0     2.739672     1.117252     0.886000     1.626375
# EUR      5008.0     1.332821     0.167570     0.975650     1.198412
# LEANHOG  5012.0   104.764001    20.342980    61.360000    89.010000
# LIVECOW  5013.0   121.237706    12.237193    93.125000   112.080000
# GOLD     5017.0  1149.336553   382.131307   600.000000   740.900000
# SP500    5019.0  1465.954070   612.399674   479.125000  1051.625000
# CORN     5022.0   551.755401   114.688345   374.000000   467.500000
# GAS_US   5023.0    14.652812     9.611705     2.731000     5.680500
# PALLAD   5024.0   634.587259   301.141832   196.450000   409.425000
# WHEAT    5024.0   943.763765   247.401890   476.500000   815.000000
# MXP      5028.0     0.049983     0.008988     0.021645     0.044049
# EDOLLAR  5029.0    92.492827     4.276914    84.189980    89.064980
# US10     5030.0    92.549121    28.291175    35.164053    69.390615
# US5      5035.0    95.509169    20.365208    53.281255    78.710942
# US20     5035.0    98.781746    35.189132    32.312550    71.499550
# JPY      5049.0     0.011128     0.001336     0.008840     0.010063
# PLAT     5062.0  1249.346940   388.745907   541.300000   935.150000
# AUD      5064.0     0.620322     0.233384     0.140900     0.475150
# GBP      5067.0     1.597251     0.218031     1.214800     1.385100
# NASDAQ   5104.0  3228.332105  1893.793382  1090.250000  1832.000000
#
#                  50%          75%          max
# US2       103.214849   107.296875   109.429688
# SOYBEAN   624.500000  1073.437500  1395.750000
# CRUDE_W    64.050000    85.305000   158.110000
# COPPER      2.894250     3.619500     5.009500
# EUR         1.373300     1.460750     1.710950
# LEANHOG   108.475000   118.430000   152.322500
# LIVECOW   121.950000   129.955000   155.200000
# GOLD     1238.300000  1415.600000  2060.900000
# SP500    1220.125000  1888.250000  3220.375000
# CORN      529.750000   594.625000   962.500000
# GAS_US     11.052000    24.980000    33.904000
# PALLAD    593.400000   775.175000  1954.000000
# WHEAT     890.500000  1078.812500  1965.000000
# MXP         0.049125     0.057137     0.069415
# EDOLLAR    91.794980    96.740000    98.780000
# US10       93.531240   120.156250   131.843750
# US5        98.414068   114.648440   121.242188
# US20       93.562550   132.828175   163.125000
# JPY         0.011043     0.012019     0.014217
# PLAT     1181.150000  1541.175000  2510.200000
# AUD         0.695800     0.776500     0.991800
# GBP         1.604800     1.741450     2.123800
# NASDAQ   2308.250000  4452.125000  8774.750000

# %%
def calc_macd(ser,s=8,l=24):
    '''
    input = series
    
    '''
    x = ser.ewm(span=(2*s-1)).mean() - ser.ewm(span=(2*l-1)).mean()
    y = x/ser.diff().ewm(span=25).std()
    y = y/y.rolling(252).std()
    return y

# %%
def get_asset(asset,df):
    df3 = df.copy(deep=True)
    df3 = df3[[asset]]
    df3.fillna(method = 'ffill',inplace=True)
    df3['dif'] = df3[asset].diff()
    df3.dropna(inplace=True)
    
    df3['macd1'] = calc_macd(df3[asset])
    df3['macd2'] = calc_macd(df3[asset],16,48)
    df3['macd3'] = calc_macd(df3[asset],32,96)
    df3['trend1'] = (df3[asset] - df3[asset].shift(1))/(df3[asset].diff().ewm(span=25).std()) # 1d
    df3['trend2'] = (df3[asset] - df3[asset].shift(21))/(df3[asset].diff().ewm(span=25).std()*np.sqrt(21)) # 1m
    df3['trend3'] = (df3[asset] - df3[asset].shift(63))/(df3[asset].diff().ewm(span=25).std()*np.sqrt(63)) # 3m
    df3['trend4'] = (df3[asset] - df3[asset].shift(126))/(df3[asset].diff().ewm(span=25).std()*np.sqrt(126)) # 6m
    df3['trend5'] = (df3[asset] - df3[asset].shift(252))/(df3[asset].diff().ewm(span=25).std()*np.sqrt(252)) # 1y

    tgt_vol = .01
    # df3['scaled_return_next'] = (df3[asset].diff()).shift(-1) # no vol scaling
    df3['scaled_return_next'] = (df3['dif']*tgt_vol/df3['dif'].ewm(span=25).std()).shift(-1)

    df3.dropna(inplace=True)
    
    return df3

# %%
asset = 'GOLD'
df3 = get_asset(asset,df2)

# %%
df3.describe()
# Out:
#               GOLD          dif        macd1        macd2        macd3  \
# count  4962.000000  4962.000000  4962.000000  4962.000000  4962.000000
# mean   1173.703688     0.187727     0.257606     0.444586     0.889047
# std     373.459817    11.471482     1.168252     1.421706     2.232327
# min     600.000000  -140.300000    -3.098782    -3.859085    -5.804066
# 25%     770.050000    -3.900000    -0.502715    -0.495532    -0.487458
# 50%    1277.100000     0.100000     0.192672     0.413735     0.896308
# 75%    1423.575000     4.600000     1.036573     1.366666     2.105755
# max    2060.900000    70.000000     4.302042     4.802498     8.650666
#
#             trend1       trend2       trend3       trend4       trend5  \
# count  4962.000000  4962.000000  4962.000000  4962.000000  4962.000000
# mean      0.043830     0.152483     0.190036     0.253234     0.285007
# std       0.955839     1.006588     0.915416     0.885738     0.883991
# min      -3.348808    -2.965097    -3.256045    -2.599433    -3.365091
# 25%      -0.532009    -0.568174    -0.439480    -0.320960    -0.314954
# 50%       0.008972     0.126295     0.231019     0.349140     0.406522
# 75%       0.651404     0.857401     0.832858     0.859695     0.911008
# max       3.525097     3.453093     3.305781     3.011049     2.683629
#
#        scaled_return_next
# count         4962.000000
# mean             0.000437
# std              0.009559
# min             -0.033488
# 25%             -0.005324
# 50%              0.000090
# 75%              0.006514
# max              0.035251

# %%
xdata = df3.iloc[:-1,2:-1].copy()
ydata = df3.iloc[:-1,-1].copy()

print(xdata.shape)
print(ydata.shape)

train_size = int(len(xdata)*.8)
test_size = len(xdata)-train_size

#change y's if multiple outputs
xtrain,xtest = xdata.iloc[0:train_size,:], xdata.iloc[train_size:len(xdata),:]
ytrain,ytest = ydata.iloc[0:train_size], ydata.iloc[train_size:len(xdata)]

print(len(xtrain),len(xtest))
print(len(ytrain),len(ytest))

scalerX = StandardScaler()
scalerY = StandardScaler()

xtrain_sc = pd.DataFrame(scalerX.fit_transform(xtrain.to_numpy()),columns=xtrain.columns,index=xtrain.index)
xtest_sc = pd.DataFrame(scalerX.transform(xtest.to_numpy()),columns=xtest.columns,index=xtest.index)
# y's are a Series
ytrain_sc = pd.DataFrame(scalerY.fit_transform(ytrain.to_numpy().reshape(-1,1)),index=ytrain.index,columns=[ytrain.name])
ytest_sc = pd.DataFrame(scalerY.transform(ytest.to_numpy().reshape(-1,1)),index=ytest.index,columns=[ytest.name])
# Out:
# (4961, 8)
# (4961,)
# 3968 993
# 3968 993

# %% [markdown]
# # Set Benchmarks: Long Only, MACD Trend (Binary), Sign Returns (Binary)

# %%
##### Long only
out = ytest_sc.copy()
out['return_next'] = scalerY.inverse_transform(out['scaled_return_next'])
out['forecast'] = np.ones(len(ytest_sc)).reshape(-1,1)
out['portfolio_returns'] = out['forecast']*out['return_next']
print('Sharpe: {}'.format(out['portfolio_returns'].mean()*np.sqrt(252)/out['portfolio_returns'].std()))
print('Mean: {}'.format(out['portfolio_returns'].mean()*252))
print('Std: {}'.format(out['portfolio_returns'].std()*np.sqrt(252)))
plt.hist(out['portfolio_returns'],bins=50);
# Out:
# Sharpe: 0.384887112726379
# Mean: 0.05788772387837618
# Std: 0.15040182423444584

# %%
##### macd trend average
out = ytest_sc.copy()
out['return_next'] = scalerY.inverse_transform(out['scaled_return_next'])
out['forecast'] = np.where(((xtest_sc['macd1'] +  xtest_sc['macd2'] + xtest_sc['macd3'])/3)>0,1,-1)
out['portfolio_returns'] = out['forecast']*out['return_next']
print('Sharpe: {}'.format(out['portfolio_returns'].mean()*np.sqrt(252)/out['portfolio_returns'].std()))
print('Mean: {}'.format(out['portfolio_returns'].mean()*252))
print('Std: {}'.format(out['portfolio_returns'].std()*np.sqrt(252)))
plt.hist(out['portfolio_returns'],bins=50);
# Out:
# Sharpe: -0.4480987454060979
# Mean: -0.06738782595288999
# Std: 0.1503861071778242

# %%
##### sign of historical returns average
out = ytest_sc.copy()
out['return_next'] = scalerY.inverse_transform(out['scaled_return_next'])
out['forecast'] = np.where(((xtest_sc['trend1'] +  xtest_sc['trend2'] + xtest_sc['trend3'] + xtest_sc['trend4']+xtest_sc['trend5'])/5)>0,1,-1)
out['portfolio_returns'] = out['forecast']*out['return_next']
print('Sharpe: {}'.format(out['portfolio_returns'].mean()*np.sqrt(252)/out['portfolio_returns'].std()))
print('Mean: {}'.format(out['portfolio_returns'].mean()*252))
print('Std: {}'.format(out['portfolio_returns'].std()*np.sqrt(252)))
plt.hist(out['portfolio_returns'],bins=50);
# Out:
# Sharpe: -0.30230711114206
# Mean: -0.045472663481050786
# Std: 0.15041876887799144

# %% [markdown]
# # Linear Model

# %% [markdown]
# ### Show that simple custom loss works for OLS

# %%
## Classic OLS first

# %%
def OLStest(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    assert len(y_true) == len(y_pred)
    
    # standard OLS
    return np.sum(np.square(y_true-y_pred))

# %%
# Generate predictors
bias = 500
true_beta = .3

# Define my "true" beta coefficients
beta = np.array([bias,true_beta]) # beta and intercept

X_raw = np.arange(1000).reshape(-1,1)
X = np.concatenate((np.ones((X_raw.shape[0],1)), X_raw), axis=1)
y_true = np.ravel(X.dot(beta))

noise = np.random.normal(0, 60, 1000)
y = y_true + noise

# %%
plt.scatter(X_raw,y)

# %%
def objective_function(beta, X, Y):
    error = OLStest(np.matmul(X,beta), Y)
    return(error)

# You must provide a starting point at which to initialize
# the parameter search space
beta_init = np.array([1]*X.shape[1])
result = minimize(objective_function, beta_init, args=(X,y),
                  method='BFGS', options={'maxiter': 500})

# The optimal values for the input parameters are stored
# in result.x
beta_hat = result.x
print('custom beta: {}'.format(beta_hat[1]))
print('custom intercept: {}'.format(beta_hat[0]))
# Out:
# custom beta: 0.2920859800516148
# custom intercept: 502.73619087739434

# %%
lm = LinearRegression()
lm.fit(X,y)
print('lm beta: {}'.format(lm.coef_[1]))
print('lm intercept: {}'.format(lm.intercept_))
# Out:
# lm beta: 0.29208590867275325
# lm intercept: 502.7362434506174

# %%
### same, all good

# %%
# test manual OLS on actual data
lm = LinearRegression()
lm.fit(xtrain_sc,ytrain_sc)


X = np.concatenate((np.ones((xtrain_sc.shape[0],1)), xtrain_sc), axis=1)

def objective_function(beta, X, Y):
    error = OLStest(np.matmul(X,beta), Y)
    return(error)

# You must provide a starting point at which to initialize
# the parameter search space
beta_init = np.random.normal(size=(X.shape[1]))
result = minimize(objective_function, beta_init, args=(X,ytrain_sc.values.ravel()),
                  method='BFGS', options={'maxiter': 500})

# The optimal values for the input parameters are stored
# in result.x
beta_hat = result.x
beta_hat

print(OLStest(np.matmul(X,beta_hat), ytrain_sc.values.ravel()))
print(OLStest(xtrain_sc.dot(lm.coef_.T)+lm.intercept_,ytrain_sc))

print(pd.DataFrame({'ols':lm.coef_.T.ravel(),'custom':beta_hat[1:].T}))

print('lm intercept: {}'.format(lm.intercept_[0]))
print('custom intercept: {}'.format(beta_hat[0]))
# Out:
# 3951.7712992236193
# 3951.771299223618
#         ols    custom
# 0  0.065287  0.065287
# 1 -0.094304 -0.094304
# 2  0.043851  0.043851
# 3 -0.011864 -0.011864
# 4 -0.006562 -0.006562
# 5 -0.048530 -0.048530
# 6  0.050386  0.050386
# 7  0.035143  0.035143
# lm intercept: -1.1282600297528854e-18
# custom intercept: -1.1049325545405504e-08

# %%
# matches, all good

# %% [markdown]
# # Asymmetric Loss Function

# %%
def CustomLoss(yTrue,yPred):
    coef = 5
    ix = (yPred*yTrue)<0
    n = np.abs(yPred - yTrue)**2
#     y = coef*yTrue**2 + np.abs(yPred-yTrue)
    y = coef*yPred**2 + np.abs(yPred-yTrue)**2
    out = np.where(ix,y,n)
    return out

def CustomLoss(yTrue,yPred):
#     ix = (yPred*yTrue)<0
    ix = np.logical_and((yPred*yTrue)>0,np.abs(yTrue)>=np.abs(yPred))
    n = ((yPred - yTrue)**2)*5
    y = (yPred-yTrue)**2
    out = np.where(ix,y,n)
    return out

# %% [markdown]
# ### Example

# %%
xs = np.linspace(-5,5,1000)
ys1 = CustomLoss(xs,1)
ys2 = CustomLoss(xs,3)
ys3 = CustomLoss(xs,-2)

# %%
fig,ax = plt.subplots(figsize=(16,8))
ax.plot(xs,ys1,linewidth=3,label='Predicted= 1')
ax.plot(xs,ys2,linewidth=3,label='Predicted= 3')
ax.plot(xs,ys3,linewidth=3,label='Predicted= -2')
ax.axvline(0,color='grey')
ax.axhline(0,color='grey')
ax.set_xlabel('Actual')
ax.set_ylabel('Loss')
ax.legend()

# %% [markdown]
# ### Back to trading rule model

# %%
class OLS():
    def __init__(self,xtrain,ytrain,xtest,ytest):
        self.xtrain = xtrain
        self.ytrain = ytrain
        self.xtest = xtest
        self.ytest = ytest
        self.scalerX = StandardScaler()
        self.scalerY = StandardScaler()
        self.model = LinearRegression()
        self.pred_sc = None
        self.pred = None
        self.results = None
        self.sharpe = None
        self.avg = None
        self.st_dev = None
        self.position = None
        
        self.rules = {1:'Binary',2:'Sine'}
        
        #Standardize Data
        self.xtrain_sc = pd.DataFrame(self.scalerX.fit_transform(self.xtrain.to_numpy()),columns=self.xtrain.columns,index=self.xtrain.index)
        self.ytrain_sc = pd.DataFrame(self.scalerY.fit_transform(self.ytrain.to_numpy().reshape(-1,1)),index=self.ytrain.index,columns=[self.ytrain.name])
        
        self.xtest_sc = pd.DataFrame(self.scalerX.transform(self.xtest.to_numpy()),columns=self.xtest.columns,index=self.xtest.index)
        self.ytest_sc = pd.DataFrame(self.scalerY.transform(self.ytest.to_numpy().reshape(-1,1)),index=self.ytest.index,columns=[self.ytest.name])
        
    def fit(self):
        self.model.fit(self.xtrain_sc,self.ytrain_sc)
        
    def predict(self):
        '''
        Predict from xtest data
        '''
        self.pred_sc = self.model.predict(self.xtest_sc)
        self.pred = self.scalerY.inverse_transform(self.pred_sc)
        self.results = self.ytest_sc.copy()
        self.results['return_next'] = self.scalerY.inverse_transform(self.results['scaled_return_next'])
        self.results['Scaled_Prediction'] = self.pred_sc
        self.results['Prediction'] = self.pred
        
        
    def calc_results(self,position=1,verbose=True,plot=False):
        '''
        Predict from xtest data using position methods:
        1 = Binary Long/Short
        2 = Sine function
        
        '''
        self.position = position
        
        if position ==1:
            self.results['Position'] = np.where(self.pred>=0,1,-1)

        elif position ==2:
            self.results['Position'] = (self.results['Prediction']/self.results['Prediction'].std()).apply(lambda x: (x*np.exp((-.25)*x**2))/(np.exp(-.5)*np.sqrt(2)))
            
        self.results['portfolio_returns'] = self.results['Position']*self.results['return_next']
        self.sharpe = self.results['portfolio_returns'].mean()*np.sqrt(252)/self.results['portfolio_returns'].std()
        self.avg = self.results['portfolio_returns'].mean()*252
        self.st_dev = self.results['portfolio_returns'].std()*np.sqrt(252)
        
        if verbose:
            print('Using ' + self.rules[self.position] + ' Rule')
            print('')
            print('Sharpe: {}'.format(self.sharpe))
            print('Mean: {}'.format(self.avg))
            print('Std: {}'.format(self.st_dev))
            print('--------------')
            
        if plot:
            fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(16,8))
            ax[0].hist(self.results['portfolio_returns'],bins=50)
            ax[0].set_title('1 Period Portfolio Returns')
            
            ax[1].scatter(self.results['Prediction'],self.results['return_next'])
            ax[1].set_title('Predicted vs. Actual Returns')
            ax[1].set_ylabel('Actual Returns')
            ax[1].set_xlabel('Predicted Returns')
            
            fig.suptitle('Using ' + self.rules[self.position] + ' Rule', fontsize=18)

# %%
class CustomLinear():
    def __init__(self,xtrain,ytrain,xtest,ytest):
        self.xtrain = xtrain
        self.ytrain = ytrain
        self.xtest = xtest
        self.ytest = ytest
        self.scalerX = StandardScaler()
        self.scalerY = StandardScaler()
#         self.model = LinearRegression()
        self.pred_sc = None
        self.pred = None
        self.results = None
        self.sharpe = None
        self.avg = None
        self.st_dev = None
        self.position = None
        
        # for custom
        self.beta_init = None
        self.result_custom = None
        self.beta_hat_custom = None
        self.method = 'BFGS'
        
        self.rules = {1:'Binary',2:'Sine'}
        
        #Standardize Data
        self.xtrain_sc = pd.DataFrame(self.scalerX.fit_transform(self.xtrain.to_numpy()),columns=self.xtrain.columns,index=self.xtrain.index)
        self.ytrain_sc = pd.DataFrame(self.scalerY.fit_transform(self.ytrain.to_numpy().reshape(-1,1)),index=self.ytrain.index,columns=[self.ytrain.name])
        
        self.xtest_sc = pd.DataFrame(self.scalerX.transform(self.xtest.to_numpy()),columns=self.xtest.columns,index=self.xtest.index)
        self.ytest_sc = pd.DataFrame(self.scalerY.transform(self.ytest.to_numpy().reshape(-1,1)),index=self.ytest.index,columns=[self.ytest.name])
        
    def Loss(self,yTrue,yPred):
        ix = np.logical_and((yPred*yTrue)>0,np.abs(yTrue)>=np.abs(yPred))
        n = ((yPred - yTrue)**(2))*2
        y = (yPred-yTrue)**2
        out = np.where(ix,y,n)
        return out
    
    def objective_function(self, beta, X, Y):
        error = np.sum(self.Loss(Y,np.matmul(X,beta)))
        return (error)
           

    def fit(self):
        # first, add bias column to Xdata
        X = np.concatenate((np.ones((self.xtrain_sc.shape[0],1)), self.xtrain_sc), axis=1)
        self.beta_init = np.random.normal(size=(X.shape[1]))
#         self.beta_init = np.ones(X.shape[1])*.1
        
        self.result_custom = minimize(self.objective_function, self.beta_init, args=(X,self.ytrain_sc.values.ravel()),
                  method=self.method, options={'maxiter': 500,'gtol':.1})
        self.beta_hat_custom = self.result_custom.x
#         print(self.result_custom.message)
        
        
    def predict(self):
        '''
        Predict from xtest data
        '''
         # first, add bias to Xdata
        
        X_test = np.concatenate((np.ones((self.xtest_sc.shape[0],1)), self.xtest_sc), axis=1)
        self.pred_sc = np.matmul(X_test,self.beta_hat_custom)
        self.pred = self.scalerY.inverse_transform(self.pred_sc)
        self.results = self.ytest_sc.copy()
        self.results['return_next'] = self.scalerY.inverse_transform(self.results['scaled_return_next'])
#         self.results['return_next'] = self.results['scaled_return_next'] ## try not scaling ys
        self.results['Scaled_Prediction'] = self.pred_sc
        self.results['Prediction'] = self.pred
        
        
    def calc_results(self,position=1,verbose=True,plot=False):
        '''
        Predict from xtest data using position methods:
        1 = Binary Long/Short
        2 = Sine function
        
        '''
        self.position = position
        
        if position ==1:
            self.results['Position'] = np.where(self.pred>=0,1,-1)

        elif position ==2:
            self.results['Position'] = (self.results['Prediction']/self.results['Prediction'].std()).apply(lambda x: (x*np.exp((-.25)*x**2))/(np.exp(-.5)*np.sqrt(2)))
            
        self.results['portfolio_returns'] = self.results['Position']*self.results['return_next']
        self.sharpe = self.results['portfolio_returns'].mean()*np.sqrt(252)/self.results['portfolio_returns'].std()
        self.avg = self.results['portfolio_returns'].mean()*252
        self.st_dev = self.results['portfolio_returns'].std()*np.sqrt(252)
        
        if verbose:
            print('Using ' + self.rules[self.position] + ' Rule')
            print('')
            print('Sharpe: {}'.format(self.sharpe))
            print('Mean: {}'.format(self.avg))
            print('Std: {}'.format(self.st_dev))
            print('--------------')
            
        if plot:
            fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(16,8))
            ax[0].hist(self.results['portfolio_returns'],bins=50)
            ax[0].set_title('1 Period Portfolio Returns')
            
            ax[1].scatter(self.results['Prediction'],self.results['return_next'])
            ax[1].set_title('Predicted vs. Actual Returns')
            ax[1].set_ylabel('Actual Returns')
            ax[1].set_xlabel('Predicted Returns')
            
            fig.suptitle('Using ' + self.rules[self.position] + ' Rule', fontsize=18)

# %%
lc = CustomLinear(xtrain,ytrain,xtest,ytest)
lc.fit()
lc.predict()
print(lc.result_custom.message)
lc.calc_results(position=1,plot=False, verbose=False)
print(lc.sharpe)
# lc.result_custom
# Out:
# Desired error not necessarily achieved due to precision loss.
# -0.6404980314210882

# %%
rs = []
for i in range(25):
    lc = CustomLinear(xtrain,ytrain,xtest,ytest)
    lc.fit()
    lc.predict()
    lc.calc_results(position=1,plot=False, verbose=False)
    rs.append(lc.sharpe)
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379876
#          Iterations: 15
#          Function evaluations: 945
#          Gradient evaluations: 85
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379930
#          Iterations: 16
#          Function evaluations: 1298
#          Gradient evaluations: 117
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379401
#          Iterations: 16
#          Function evaluations: 2426
#          Gradient evaluations: 219
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379036
#          Iterations: 14
#          Function evaluations: 923
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380076
#          Iterations: 15
#          Function evaluations: 667
#          Gradient evaluations: 60
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380398
#          Iterations: 14
#          Function evaluations: 1314
#          Gradient evaluations: 119
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380910
#          Iterations: 14
#          Function evaluations: 803
#          Gradient evaluations: 72
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380274
#          Iterations: 15
#          Function evaluations: 809
#          Gradient evaluations: 73
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380470
#          Iterations: 15
#          Function evaluations: 836
#          Gradient evaluations: 75
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.381256
#          Iterations: 12
#          Function evaluations: 821
#          Gradient evaluations: 74
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.386677
#          Iterations: 15
#          Function evaluations: 957
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.381499
#          Iterations: 12
#          Function evaluations: 1204
#          Gradient evaluations: 109
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380694
#          Iterations: 14
#          Function evaluations: 1448
#          Gradient evaluations: 131
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380777
#          Iterations: 13
#          Function evaluations: 579
#          Gradient evaluations: 52
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380683
#          Iterations: 14
#          Function evaluations: 789
#          Gradient evaluations: 71
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.378849
#          Iterations: 16
#          Function evaluations: 868
#          Gradient evaluations: 78
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379512
#          Iterations: 16
#          Function evaluations: 867
#          Gradient evaluations: 78
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380569
#          Iterations: 13
#          Function evaluations: 733
#          Gradient evaluations: 66
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.381076
#          Iterations: 14
#          Function evaluations: 899
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.381215
#          Iterations: 14
#          Function evaluations: 918
#          Gradient evaluations: 83
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380119
#          Iterations: 14
#          Function evaluations: 1220
#          Gradient evaluations: 110
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.381149
#          Iterations: 13
#          Function evaluations: 789
#          Gradient evaluations: 71
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379780
#          Iterations: 15
#          Function evaluations: 1949
#          Gradient evaluations: 176
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.381300
#          Iterations: 13
#          Function evaluations: 699
#          Gradient evaluations: 63
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.380060
#          Iterations: 17
#          Function evaluations: 1566
#          Gradient evaluations: 141

# %%
np.array(rs).mean()
# Out:
# -0.5991320059627852

# %%
np.array(rs).std()
# Out:
# 0.00865220906110544

# %%
lc = CustomLinear(xtrain,ytrain,xtest,ytest)
lc.fit()
lc.predict()
lc.calc_results(position=1,plot=True, verbose=True)
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.379408
#          Iterations: 14
#          Function evaluations: 857
#          Gradient evaluations: 77
# Using Binary Rule
#
# Sharpe: -0.5973658811838191
# Mean: -9.323864099276848
# Std: 15.608297013547961
# --------------

# %%
lm = OLS(xtrain,ytrain,xtest,ytest)
lm.fit()
lm.predict()
lm.calc_results(position=1,plot=True)
lm.calc_results(position=2,plot=True)
# Out:
# Using Binary Rule
#
# Sharpe: 0.09751768940440692
# Mean: 0.014718061420416541
# Std: 0.15092709343615168
# --------------
# Using Sine Rule
#
# Sharpe: 0.22910819374679062
# Mean: 0.02372589232585783
# Std: 0.10355758970401376
# --------------

# %%
lm.xtrain_sc.corr()
# Out:
#            macd1     macd2     macd3    trend1    trend2    trend3    trend4  \
# macd1   1.000000  0.860965  0.570558  0.073549  0.768472  0.850906  0.668876
# macd2   0.860965  1.000000  0.858165  0.040784  0.474981  0.840735  0.839212
# macd3   0.570558  0.858165  1.000000  0.025608  0.251411  0.579764  0.779532
# trend1  0.073549  0.040784  0.025608  1.000000  0.247484  0.140798  0.109235
# trend2  0.768472  0.474981  0.251411  0.247484  1.000000  0.575382  0.428547
# trend3  0.850906  0.840735  0.579764  0.140798  0.575382  1.000000  0.672265
# trend4  0.668876  0.839212  0.779532  0.109235  0.428547  0.672265  1.000000
# trend5  0.526174  0.715783  0.812452  0.086007  0.346291  0.497369  0.736392
#
#           trend5
# macd1   0.526174
# macd2   0.715783
# macd3   0.812452
# trend1  0.086007
# trend2  0.346291
# trend3  0.497369
# trend4  0.736392
# trend5  1.000000

# %%
sharpes = []
vols = []
ols_binary = 0
ols_sine = 0
cust_binary = 0
cust_sine = 0


for asset in assets:
    asset_df = get_asset(asset,df2)

    #changes needed if multiple outputs

    xdata = asset_df.iloc[:-1,2:-1]
    ydata = asset_df.iloc[:-1,-1]

    train_size = int(len(xdata)*.75)
    test_size = len(xdata)-train_size

    xtrain,xtest = xdata.iloc[0:train_size,:], xdata.iloc[train_size:len(xdata),:]
    ytrain,ytest = ydata.iloc[0:train_size], ydata.iloc[train_size:len(xdata)]

    lm = OLS(xtrain,ytrain,xtest,ytest)
    lm.fit()
    lm.predict()
    lm.calc_results(position=1,verbose=False, plot=False)
    ols_binary = (lm.sharpe,lm.st_dev)
    lm.calc_results(position=2,verbose=False, plot=False)
    ols_sine = (lm.sharpe,lm.st_dev)
    
    lc = CustomLinear(xtrain,ytrain,xtest,ytest)
    lc.fit()
    lc.predict()
    lc.calc_results(position=1,verbose=False, plot=False)
    cust_binary = (lc.sharpe, lc.st_dev)
    lc.calc_results(position=2,verbose=False, plot=False)
    cust_sine = (lc.sharpe, lc.st_dev)


    sharpes.append((asset,ols_binary[0],ols_sine[0],cust_binary[0],cust_sine[0]))
    vols.append((asset,ols_binary[1],ols_sine[1],cust_binary[1],cust_sine[1]))
# Out:
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.
# Desired error not necessarily achieved due to precision loss.

# %%
X2 = np.concatenate((np.ones((lc.xtrain_sc.shape[0],1)), lc.xtrain_sc), axis=1)
t = np.matmul(X2,lc.beta_hat_custom)
lc.Loss(lc.ytrain_sc.to_numpy().ravel(),t).sum()
# Out:
# 4064.831714519065

# %%
sharpes_all = pd.DataFrame(
    data=np.array(sharpes)[:,1:].astype('float32'),
    index=np.array(sharpes)[:,0],
    columns=['OLS_Binary_Rule','OLS_Sine_Rule','Cust_Binary_Rule','Cust_Sine_Rule']
)
sharpes_all
# Out:
#          OLS_Binary_Rule  OLS_Sine_Rule  Cust_Binary_Rule  Cust_Sine_Rule
# AUD            -0.852418      -0.442922         -0.061585        0.282989
# COPPER         -0.016029      -0.061224         -0.093085       -0.093855
# CORN           -0.138743      -0.030445         -0.173028        0.233865
# CRUDE_W        -0.167169       0.098736          0.172749        0.076325
# EDOLLAR         0.181286       0.033836          0.234472       -0.277478
# EUR             0.088841      -0.034368          0.216618        0.139248
# GAS_US          0.452287       0.634994          0.583690        0.658063
# GBP            -0.451536      -0.424396         -0.017325        0.116975
# GOLD           -0.184648       0.265762          0.356663       -0.063639
# JPY            -0.061028      -0.114301          0.168806        0.162215
# LEANHOG         0.368128       0.232134         -0.470915       -0.504835
# LIVECOW        -0.243847      -0.069638         -0.266519       -0.007992
# MXP             0.347474       0.306781          0.136358        0.263691
# NASDAQ          1.249372       1.313132          1.287537        0.995628
# PALLAD          0.425330       0.466665          0.598799        0.452452
# PLAT            0.142968       0.165280         -0.250513       -0.159383
# SOYBEAN        -0.155893      -0.222728         -0.096633       -0.364055
# SP500           0.857478       0.985468          0.935975        1.072920
# US10           -0.055363      -0.025547          0.231417        0.451235
# US2            -0.705898      -0.551452         -0.360353        0.196959
# US20            0.307546       0.066626          0.373624        0.110753
# US5            -0.899359      -0.587380          0.285606       -0.024007
# WHEAT           0.097518       0.229108         -0.332167       -0.343600

# %%
sharpes_all.mean()
# Out:
# OLS_Binary_Rule     0.025491
# OLS_Sine_Rule       0.097136
# Cust_Binary_Rule    0.150443
# Cust_Sine_Rule      0.146716
# dtype: float32

# %%
vols_all = pd.DataFrame(
    data=np.array(vols)[:,1:].astype('float32'),
    index=np.array(vols)[:,0],
    columns=['OLS_Binary_Rule','OLS_Sine_Rule','Cust_Binary_Rule','Cust_Sine_Rule']
)
vols_all.round(5)
# Out:
#          OLS_Binary_Rule  OLS_Sine_Rule  Cust_Binary_Rule  Cust_Sine_Rule
# AUD              0.15085        0.10754           0.15107         0.00004
# COPPER           0.14981        0.10507           0.14981         0.10872
# CORN             0.14831        0.09721           0.14831         0.10015
# CRUDE_W          0.15035        0.10998           0.15035         0.06066
# EDOLLAR          0.15161        0.11197           0.15160         0.03314
# EUR              0.14902        0.10655           0.14901         0.11288
# GAS_US           0.15227        0.11025           0.15223         0.10332
# GBP              0.15007        0.10276           0.15013         0.10818
# GOLD             0.15163        0.10732           0.15160         0.01479
# JPY              0.15021        0.10362           0.15021         0.11099
# LEANHOG          0.15345        0.11262           0.15342         0.02681
# LIVECOW          0.15303        0.09967           0.15303         0.09730
# MXP              0.15072        0.10429           0.15075         0.10211
# NASDAQ           0.15035        0.10256           0.15032         0.02273
# PALLAD           0.15481        0.10848           0.15476         0.10897
# PLAT             0.15242        0.10763           0.15241         0.01197
# SOYBEAN          0.14953        0.10713           0.14953         0.11664
# SP500            0.14903        0.10920           0.14899         0.11156
# US10             0.15219        0.11402           0.15218         0.05186
# US2              0.14872        0.10678           0.14883         0.01720
# US20             0.15181        0.11555           0.15179         0.10534
# US5              0.15133        0.11131           0.15155         0.10332
# WHEAT            0.15093        0.10356           0.15090         0.11729

# %% [markdown]
# # Custom Loss

# %%
def CustomLoss(yTrue,yPred):
    coef = .005 #### Need to validate
    ix = (yPred*yTrue)<0
    n = np.abs(yPred - yTrue)**2
#     y = coef*yTrue**2 + np.abs(yPred-yTrue)
#     y = coef*yPred**2 + np.abs(yPred-yTrue)
    y = (np.abs(yPred-yTrue)**2)*10
    out = np.where(ix,y,n)
    return out

X = np.concatenate((np.ones((xtrain_sc.shape[0],1)), xtrain_sc), axis=1)

def objective_function(beta, X, Y):
    error = np.sum(CustomLoss(Y,np.matmul(X,beta)))
    return(error)

beta_init = np.random.normal(size=(X.shape[1]))
result_custom = minimize(objective_function, beta_init, args=(X,ytrain_sc.values.ravel()),
                  method='BFGS', options={'maxiter': 500,'gtol': 1e-08})

beta_hat_custom = result_custom.x
print(beta_hat_custom)
print(objective_function(beta_hat_custom,X,ytrain_sc.values.ravel()))
# Out:
# [-0.00023295 -0.00791435  0.00662656 -0.0053408  -0.00202985  0.00539308
#  -0.00350448 -0.00095653  0.00756755]
# 21827.76272709182

# %%
##### lots of near 0 positions, so lot of extreme -1/+1 flips for small change in weights

# %%
# to do:
## wrap train/test split into function
## wrap forecast x returns + results into function
## wrap entire process for 1 asset into class

# %%
#function for building multiple days worth of data

# %%
xtest_sc.shape
# Out:
# (993, 8)

# %%
def data_transform(x_data, y_data, num_steps=10):
    """ Changes data to the format for LSTM training 
    for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        # if index is larger than the size of the dataset, we stop
        if end_ix >= x_data.shape[0]:
            break
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix]
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %%
xtest_sc.head()
# Out:
#                macd1     macd2     macd3    trend1    trend2    trend3  \
# DATETIME
# 2016-03-10  1.399809  1.172424  0.058365  1.405409  0.944283  1.815317
# 2016-03-11  1.231601  1.059032  0.042235 -1.477686 -0.134899  1.495197
# 2016-03-14  1.134429  1.024160  0.048950 -1.027189 -0.209846  1.214200
# 2016-03-15  1.092630  1.042008  0.073310 -0.271509 -0.257069  1.498471
# 2016-03-16  0.958337  0.915348  0.043218  1.848287  0.640108  1.468848
#
#               trend4    trend5
# DATETIME
# 2016-03-10  0.766642  0.016741
# 2016-03-11  0.477164 -0.109000
# 2016-03-14  0.322513 -0.207805
# 2016-03-15  0.367549 -0.193894
# 2016-03-16  0.547636 -0.030433

# %%
ytest_sc.tail()
# Out:
#             scaled_return_next
# DATETIME
# 2019-12-24            1.414220
# 2019-12-25            0.451407
# 2019-12-26            1.361672
# 2019-12-27           -0.096868
# 2019-12-30            1.432671

# %%
newx, newy = data_transform(xtest_sc.to_numpy(),ytest_sc.to_numpy(),num_steps=5)

# %%
newx.shape
# Out:
# (988, 5, 8)

# %%
newx.shape[1]*newx.shape[2]
# Out:
# 40

# %%
newx.reshape(newx.shape[0],newx.shape[1]*newx.shape[2]).shape
# Out:
# (988, 40)
